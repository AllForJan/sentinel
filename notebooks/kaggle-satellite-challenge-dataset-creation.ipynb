# %% [markdown]
# # satellite image objects
# * hierarchical class built structures:
#     1. Buildings - large building, residential, non-residential, fuel storage facility, fortified building
#     2. Misc. Manmade structures
# * hierarchical class pathways:
#     3. Road
#     4. Track - poor/dirt/cart track, footpath/trail
# * hierarchical class vegetation:
#     5. Trees - woodland, hedgerows, groups of trees, standalone trees
#     6. Crops - contour ploughing/cropland, grain (wheat) crops, row (potatoes, turnips) crops
# * hierarchical class water:
#     7. Waterway
#     8. Standing water

# %%
# data downloaded using Kaggle-CLI
ll -h '/mnt/data/sentinel/dstl-satellite-imagery-feature-detection/train_geojson_v3'
# Out:
# total 100K
# drwx------ 2 adrian 4,0K  6 dec  2016 6010_1_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6010_4_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6010_4_4/
# drwx------ 2 adrian 4,0K  6 dec  2016 6040_1_0/
# drwx------ 2 adrian 4,0K  6 dec  2016 6040_1_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6040_2_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6040_4_4/
# drwx------ 2 adrian 4,0K  6 dec  2016 6060_2_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6070_2_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6090_2_0/
# drwx------ 2 adrian 4,0K  6 dec  2016 6100_1_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6100_2_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6100_2_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6110_1_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6110_3_1/
# drwx------ 2 adrian 4,0K  6 dec  2016 6110_4_0/
# drwx------ 2 adrian 4,0K  6 dec  2016 6120_2_0/
# drwx------ 2 adrian 4,0K  6 dec  2016 6120_2_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6140_1_2/
# drwx------ 2 adrian 4,0K  6 dec  2016 6140_3_1/
# drwx------ 2 adrian 4,0K  6 dec  2016 6150_2_3/
# drwx------ 2 adrian 4,0K  6 dec  2016 6160_2_1/
# drwx------ 2 adrian 4,0K  6 dec  2016 6170_0_4/
# drwx------ 2 adrian 4,0K  6 dec  2016 6170_2_4/
# drwx------ 2 adrian 4,0K  6 dec  2016 6170_4_1/

# %% [markdown]
# ## Dataset

# %%
import sys
sys.path.append('../')

from importlib import reload

# %load_ext autoreload
# %autoreload 2

# %%
import sentinel.data
reload(sentinel.data)
from sentinel.data import load_dataset

# hard-coded: DATA_PATH = '/mnt/data/sentinel/dstl-satellite-imagery-feature-detection'
# %time sentinel_df = load_dataset()
# Out:
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed | 25.6s
# /home/adrian/.pyenv/versions/miniconda3-latest/envs/sentinel/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# CPU times: user 2min 31s, sys: 447 ms, total: 2min 31s
# Wall time: 2min 31s

# %%
sentinel_df.shape
# Out:
# (25, 12)

# %% [markdown]
# # observe dataframe information

# %%
import numpy as np
from shapely.geometry import MultiPolygon, Polygon
import shapely.affinity
import sentinel.data.write
# reload(sentinel.data.write)
from sentinel.data.write import process_classes, scale_to_mask, LABEL_RANGE, get_file, LABEL_COLUMNS
from sentinel.data import read_image, stretch_8bit, HIERARCHIES

df_row = sentinel_df[sentinel_df.image_id == '6060_2_3']
image = stretch_8bit(read_image(df_row.image_id.values[0], 'three_band/{}.tif'))
mask = process_classes(image.shape[:2], df_row)
print(np.unique(mask))
# Out:
# 5
# [0 1 2 3 4]

# %%
import sentinel.visualization
reload(sentinel.visualization)
from sentinel.visualization import discrete_cmap, colorbar
import matplotlib.pyplot as plt
# %matplotlib inline

labels = HIERARCHIES
# labels = LABEL_COLUMNS[::-1]
N = len(labels)
ticks = range(N)

cmap = discrete_cmap(N, 'cubehelix')
fig, (ax0, ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 6, figsize=[30, 15])
ax0.imshow(image)
ax1.imshow(mask[...,0], interpolation='nearest', cmap=cmap)
ax1.set_title(labels[1])
ax2.imshow(mask[...,1], interpolation='nearest', cmap=cmap)
ax2.set_title(labels[2])
ax3.imshow(mask[...,2], interpolation='nearest', cmap=cmap)
ax3.set_title(labels[3])
ax4.imshow(mask[...,3], interpolation='nearest', cmap=cmap)
ax4.set_title(labels[4])
ax5.imshow(mask[...,4], interpolation='nearest', cmap=cmap)
ax5.set_title(labels[5])
# img1 = ax1.imshow(mask, interpolation='nearest', cmap=cmap)
# colorbar(img1, ticks=ticks, labels=labels)
# Out:
# Text(0.5,1,'WATER')

# %% [markdown]
# # write dataset into TF records

# %%
rm -rf /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/*

# %%
import sentinel.data
reload(sentinel.data)
from sentinel.data import save

for i, df_row in sentinel_df.iterrows():
    save(df_row, save_folder='tfrecords/multi-binary', num_rows=2, num_cols=2, use_sparse=False)
# Out:
# 3
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-part-4.tfrecord
# 1
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-part-4.tfrecord
# 3
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-part-4.tfrecord
# 5
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-part-4.tfrecord
# 5
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-part-4.tfrecord
# 8
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-part-4.tfrecord
# 4
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-part-4.tfrecord
# 4
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-part-4.tfrecord
# 5
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-2-4-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-2-4-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-2-4-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-2-4-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-4-1-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-4-1-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-4-1-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-4-1-part-4.tfrecord

# %%
import sentinel.data
reload(sentinel.data)
from sentinel.data import save

for i, df_row in sentinel_df.iterrows():
    save(df_row, save_folder='tfrecords/multi-binary', num_rows=2, num_cols=2, use_sparse=True)
# Out:
# 3
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-1-2-sparse-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-2-sparse-part-4.tfrecord
# 1
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6010-4-4-sparse-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-0-sparse-part-4.tfrecord
# 3
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-1-3-sparse-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-2-2-sparse-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6040-4-4-sparse-part-4.tfrecord
# 5
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6060-2-3-sparse-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6070-2-3-sparse-part-4.tfrecord
# 5
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6090-2-0-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-1-3-sparse-part-4.tfrecord
# 8
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-2-sparse-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6100-2-3-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-1-2-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-3-1-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6110-4-0-sparse-part-4.tfrecord
# 6
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-0-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6120-2-2-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-1-2-sparse-part-4.tfrecord
# 7
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6140-3-1-sparse-part-4.tfrecord
# 4
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6150-2-3-sparse-part-4.tfrecord
# 2
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-sparse-part-3.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6160-2-1-sparse-part-4.tfrecord
# 4
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-sparse-part-1.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-sparse-part-2.tfrecord
# /mnt/data/sentinel/dstl-satellite-imagery-feature-detection/tfrecords/multi-binary/6170-0-4-sparse-part-3.tfrecord
